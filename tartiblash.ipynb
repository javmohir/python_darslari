# %% [markdown]
# <a href="https://colab.research.google.com/github/javmohir/python_darslari/blob/main/tartiblash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pprint import pprint as print

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df.shape
# Out:
# (13119, 9)

# %%
df.tail()
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9

# %%
df.sample(10)
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 4513      C Class  2015  14490    Semi-Auto    51866   Diesel   20  64.2
# 5630    GLA Class  2017  16300       Manual    25150   Diesel   20  67.3
# 6447     SL CLASS  2016  18950       Manual    17358   Petrol  160  43.5
# 2185      A Class  2016  13995    Semi-Auto    64168   Diesel   20  67.3
# 6325      E Class  2018  34749    Automatic    12458   Diesel  145  41.5
# 8759      C Class  2019  33149    Semi-Auto     9000   Diesel  145  54.3
# 142       E Class  2017  20998    Semi-Auto    21352   Diesel   20  72.4
# 12346     C Class  2016  13000       Manual    22886   Diesel   20  70.6
# 5350    GLA Class  2020  29991    Semi-Auto     1786   Petrol  145  35.8
# 764       A Class  2017  17047    Semi-Auto    14951   Diesel  145  68.9
#
#        engineSize
# 4513          2.1
# 5630          2.1
# 6447          2.0
# 2185          2.1
# 6325          3.0
# 8759          2.0
# 142           2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         13119 non-null  object
#  1   year          13119 non-null  int64
#  2   price         13119 non-null  int64
#  3   transmission  13119 non-null  object
#  4   mileage       13119 non-null  int64
#  5   fuelType      13119 non-null  object
#  6   tax           13119 non-null  int64
#  7   mpg           13119 non-null  float64
#  8   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 922.6+ KB

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df['year'].plot.hist(bins=30)

# %%
data={
    'age':[10,20,30,40,50,60],
    'year':[2010, 2000, 1990, 1980, 1970, 1960]
}
obj=pd.DataFrame(data)

# %%
obj
# Out:
#    age  year
# 0   10  2010
# 1   20  2000
# 2   30  1990
# 3   40  1980
# 4   50  1970
# 5   60  1960

# %%
obj['age'].corr(obj['year'])
# Out:
# -0.9999999999999998

# %%
df['year'].corr(df['mileage'])
# Out:
# -0.7380268515364232

# %%
df['price'].corr(df['mileage'])
# Out:
# -0.537214124104646

# %%
df.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
df['price'].corr(df['mileage'])
# Out:
# -0.537214124104646

# %%
df.corrwith(df['price'])
# Out:
# year          0.520712
# price         1.000000
# mileage      -0.537214
# tax           0.268717
# mpg          -0.438445
# engineSize    0.516126
# dtype: float64

# %%
df
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# ...

# %%
df['model'].unique()
# Out:
# array([' SLK', ' S Class', ' SL CLASS', ' G Class', ' GLE Class',
#        ' GLA Class', ' A Class', ' B Class', ' GLC Class', ' C Class',
#        ' E Class', ' GL Class', ' CLS Class', ' CLC Class', ' CLA Class',
#        ' V Class', ' M Class', ' CL Class', ' GLS Class', ' GLB Class',
#        ' X-CLASS', '180', ' CLK', ' R Class', '230', '220', '200'],
#       dtype=object)

# %%
models=df['model'].unique()
models.sort()
models
# Out:
# array([' A Class', ' B Class', ' C Class', ' CL Class', ' CLA Class',
#        ' CLC Class', ' CLK', ' CLS Class', ' E Class', ' G Class',
#        ' GL Class', ' GLA Class', ' GLB Class', ' GLC Class',
#        ' GLE Class', ' GLS Class', ' M Class', ' R Class', ' S Class',
#        ' SL CLASS', ' SLK', ' V Class', ' X-CLASS', '180', '200', '220',
#        '230'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([2005, 2017, 2016, 2011, 2018, 2012, 2019, 2020, 2014, 2015, 2006,
#        2010, 2004, 2008, 2013, 2007, 2009, 2003, 2001, 2002, 1998, 2000,
#        1997, 1999, 1970])

# %%
years=df['year'].unique()
years.sort()
years
# Out:
# array([1970, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#        2018, 2019, 2020])

# %%
df['year'].value

# %%
df['fuelType'].unique()
# Out:
# array(['Petrol', 'Hybrid', 'Diesel', 'Other'], dtype=object)

# %%
df['model'].value_counts()
# Out:
#  C Class      3747
#  A Class      2561
#  E Class      1953
#  GLC Class     960
#  GLA Class     847
#  B Class       591
#  CL Class      511
#  GLE Class     461
#  SL CLASS      260
#  CLS Class     237
#  V Class       207
#  S Class       197
#  GL Class      121
#  SLK            95
#  CLA Class      86
#  X-CLASS        82
#  M Class        79
#  GLS Class      74
#  GLB Class      19
#  G Class        15
#  CLK             7
#  CLC Class       3
#  R Class         2
# 180              1
# 230              1
# 220              1
# 200              1
# Name: model, dtype: int64

# %%
df['year'].value_counts()
# Out:
# 2019    4553
# 2017    2381
# 2016    1971
# 2018    1467
# 2015     991
# 2020     719
# 2014     491
# 2013     292
# 2012      57
# 2011      38
# 2010      38
# 2007      22
# 2009      17
# 2008      16
# 2004      13
# 2001      10
# 2002       9
# 2005       9
# 2006       8
# 2003       7
# 1998       4
# 2000       3
# 1997       1
# 1999       1
# 1970       1
# Name: year, dtype: int64

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# ...

# %%
df['fuelType'].value_counts()
# Out:
# Diesel    9187
# Petrol    3752
# Hybrid     173
# Other        7
# Name: fuelType, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# Semi-Auto    6848
# Automatic    4825
# Manual       1444
# Other           2
# Name: transmission, dtype: int64

# %%
df['model'].unique()
# Out:
# array([' SLK', ' S Class', ' SL CLASS', ' G Class', ' GLE Class',
#        ' GLA Class', ' A Class', ' B Class', ' GLC Class', ' C Class',
#        ' E Class', ' GL Class', ' CLS Class', ' CLC Class', ' CLA Class',
#        ' V Class', ' M Class', ' CL Class', ' GLS Class', ' GLB Class',
#        ' X-CLASS', '180', ' CLK', ' R Class', '230', '220', '200'],
#       dtype=object)

# %%
models=[' SLK',' B Class']
feltir=df['model'].isin(models)
feltir
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13114    False
# 13115     True
# 13116    False
# 13117    False
# 13118    False
# Name: model, Length: 13119, dtype: bool

# %%
df[feltir]
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0           SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 12      B Class  2019  23750    Automatic      278   Diesel  145  55.4
# 15      B Class  2017  15890    Automatic    24841   Diesel  150  68.9
# 18      B Class  2017  17513    Automatic    14128   Diesel  150  68.9
# 40          SLK  2014  15990    Automatic    43955   Petrol  205  43.5
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 13033   B Class  2016  14599    Automatic    28156   Diesel   20  68.9
# 13073   B Class  2019  19350    Automatic    13674   Petrol  145  45.6
# 13108       SLK  2016  17499    Automatic    30128   Diesel   30  70.6
# 13111   B Class  2019  19344    Automatic    15257   Petrol  145  45.6
# 13115   B Class  2020  24699    Automatic     2500   Diesel  145  55.4
#
#        engineSize
# 0             1.8
# 12            2.0
# 15            1.5
# 18            2.1
# ...

# %%
oil=df['fuelType'].isin(['Petrol','Diesel'])

# %%
df[oil]
# Out:
#             model  year   price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005    5200    Automatic    63000   Petrol  325  32.1
# 2        SL CLASS  2016   49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016   61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016   73948    Automatic     4000   Petrol  325  30.1
# 5        SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
# ...           ...   ...     ...          ...      ...      ...  ...   ...
# 13114     C Class  2020   35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020   24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019   30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019   37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019   54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 2             5.5
# 3             4.0
# ...

# %%
df[(df.year>=2018)&(df.price<20000)&(df.fuelType=='Petrol')]
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 93      A Class  2019  19840    Automatic     6781   Petrol  145  28.5
# 158     A Class  2019  18995    Semi-Auto    21400   Petrol  145  53.3
# 238     A Class  2018  19995    Semi-Auto     2348   Petrol  145  53.3
# 294     C Class  2018  19998    Semi-Auto    15383   Petrol  145  46.3
# 384     A Class  2018  17498    Semi-Auto    15316   Petrol  145  49.6
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 12993   B Class  2019  19345    Automatic    14082   Petrol  145  45.6
# 13000   A Class  2018  16500    Semi-Auto    14289   Petrol  150  49.6
# 13018   A Class  2018  17600    Automatic    15893   Petrol  145  52.3
# 13073   B Class  2019  19350    Automatic    13674   Petrol  145  45.6
# 13111   B Class  2019  19344    Automatic    15257   Petrol  145  45.6
#
#        engineSize
# 93            1.3
# 158           1.3
# 238           1.3
# 294           1.5
# ...

# %%
df3=df[(df.price>=2018)&(df.mileage<10000)&(df.price<20000)]

# %%
df3
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 93        A Class  2019  19840    Automatic     6781   Petrol  145  28.5
# 125     CLA Class  2017  18790    Automatic     8423   Diesel  150  67.3
# 132       A Class  2017  18890    Automatic     7875   Petrol  150  53.3
# 224       A Class  2017  18298    Semi-Auto     7919   Diesel  145  68.9
# 238       A Class  2018  19995    Semi-Auto     2348   Petrol  145  53.3
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 12885     B Class  2017  15995    Automatic     6000   Diesel  145  67.3
# 12961     A Class  2019  19888       Manual     9071   Petrol  145  53.3
# 13013     B Class  2018  17995    Automatic     6025   Diesel  145  68.9
# 13014     B Class  2017  13950       Manual     5878   Diesel   20  68.9
# 13042     C Class  2017  18490    Automatic     8060   Petrol  150  50.4
#
#        engineSize
# 93            1.3
# 125           2.1
# 132           1.6
# ...

# %%
df[df.transmission=='Automatic']
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# ...

# %%
df[df.fuelType=='Hybrid']
# Out:
#           model  year  price transmission  mileage fuelType  tax    mpg  \
# 1       S Class  2017  34948    Automatic    27000   Hybrid   20   61.4
# 77      S Class  2016  24880    Automatic    75000   Hybrid  190   42.4
# 137     C Class  2017  21000    Automatic    25000   Hybrid  140  134.5
# 327     E Class  2019  39998    Semi-Auto     2675   Hybrid  135  134.5
# 329     C Class  2016  18498    Semi-Auto    31891   Hybrid    0  134.5
# ...         ...   ...    ...          ...      ...      ...  ...    ...
# 12687   C Class  2017  17480    Automatic    47019   Hybrid    0  134.5
# 12707   S Class  2019  56890    Automatic     2931   Hybrid  135  100.9
# 12713   C Class  2017  20480    Automatic    30053   Hybrid    0  134.5
# 12867   S Class  2017  36890    Automatic    22657   Hybrid   20   61.4
# 12999   C Class  2016  15999    Automatic    66077   Hybrid    0  134.5
#
#        engineSize
# 1             2.1
# 77            3.5
# 137           2.0
# 327           2.0
# ...
